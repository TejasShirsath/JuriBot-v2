# %%
# !pip install -U langchain langchain-community langchain-openai faiss-cpu pypdf sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached langchain-1.2.10-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached sentence_transformers-5.2.2-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached langgraph-1.0.8-py3-none-any.whl.metadata (7.4 kB)
# ...
# Using cached langchain-1.2.10-py3-none-any.whl (111 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached sentence_transformers-5.2.2-py3-none-any.whl (494 kB)
# Using cached langgraph-1.0.8-py3-none-any.whl (158 kB)
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_openai import ChatOpenAI

# %%
pdf_path = "sample_pdf/contract.pdf"   # change to your file

loader = PyPDFLoader(pdf_path)
documents = loader.load()

print("Pages loaded:", len(documents))
print(documents[0].page_content[:300])
# Out:
# Pages loaded: 10
# Page 1
# Sample Contract
#
# Contract No.___________
# PROFESSIONAL SERVICES AGREEMENT
#
#
# THIS AGREEMENT made and entered into this _______day of                       , 20
#  by and between the SANTA
# CRUZ COUNTY REGIONAL TRANSPORTATION COMMISSION, hereinafter called COMMISSION, and
# ________

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = splitter.split_documents(documents)

print("Total chunks:", len(chunks))
# Out:
# Total chunks: 77

# %%
import os
os.environ["HF_TOKEN"] = "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"

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)

db = FAISS.from_documents(chunks, embeddings)

db.save_local("juribot_index")

print("Vector DB created ✅")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Vector DB created ✅

# %%
# !pip install -U langchain-ollama
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# ...
# Using cached ollama-0.6.1-py3-none-any.whl (14 kB)
# ...
# Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
# ...

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="qwen3:4b",
    base_url="http://localhost:11434",
    temperature=0
)

# %%
retriever = db.as_retriever(search_kwargs={"k": 3})

# %%
question = "What is this document about?"

docs = retriever.invoke(question)

# %%
context = "\n\n".join([d.page_content for d in docs])

prompt = f"""
You are Juribot, a legal assistant.

Context:
{context}

Question:
{question}

Answer clearly:
"""

# %%
response = llm.invoke(prompt)
print(response.content)
# Out:
# Based on the provided context, **this document is a government contract agreement** between a **state or federal government entity** (referred to as the "COMMISSION" or "Agency") and a **Consultant** (a contractor or service provider).
#
# ### Key Details Explained:
# 1. **Type of Document**:
#    - A **federal/state government contract** (specifically referencing the **Federal Highway Administration (FHWA)** and **California Code of Regulations**).
#    - The "COMMISSION" here likely refers to a regulatory body (e.g., a state transportation agency or federal entity like the FHWA).
#
# 2. **Core Purpose**:
#    - To define **audit and inspection rights** for government entities.
#    - Explicitly grants the COMMISSION, state agencies, and FHWA the authority to:
#      - Access the Consultant’s books, records, and documents for audits, examinations, or inspections.
#      - Require copies of such documents if requested.
# ...
